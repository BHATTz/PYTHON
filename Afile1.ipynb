# %%
import pandas as pd
df = pd.read_csv("C:\\Users\sarth\OneDrive\Documents\#LAB\PY\heart.csv") 
mean1 = df['trestbps'].mean()
median1 = df['trestbps'].median() 
mode1 = df['trestbps'].mode() 
print('mean trestbps: ' + str(mean1))
print('median trestbps: ' + str(median1))
print('mode trestbps: ' + str(mode1))
# Out:
# mean trestbps: 131.61170731707318
# median trestbps: 130.0
# mode trestbps: 0    120
# Name: trestbps, dtype: int64

# %%
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb
data = pd.read_csv("C:\\Users\sarth\OneDrive\Documents\#LAB\PY\ll.csv")
print(data.corr())
dataplot = sb.heatmap(data.corr(), cmap="YlGnBu", annot=True)
mp.show()
# Out:
#                   Distance (miles)   "Fare ($)"
# Distance (miles)          1.000000     0.996515
#  "Fare ($)"               0.996515     1.000000

# %%
import numpy as np
import matplotlib.pyplot as plt
data = {'C':20, 'C++':15, 'Java':30,'Python':35}
courses = list(data.keys())
values = list(data.values())  
fig = plt.figure(figsize = (10, 5))
plt.bar(courses, values, color ='green',width = 0.4) 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
import matplotlib.pyplot as plt
x =[5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y =[99, 86, 87, 88, 100, 86, 103, 87, 94, 78, 77, 85, 86]
plt.scatter(x, y, c ="green")
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
a = np.array([22, 87, 5, 43, 56, 73, 55, 54, 11, 20, 51, 5, 79, 31, 27])
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(a, bins = [0, 25, 50, 75, 100])
plt.show()

# %%
import matplotlib.pyplot as plt
fig, gnt = plt.subplots()
gnt.set_ylim(0, 50)
gnt.set_xlim(0, 160)
gnt.set_xlabel('seconds since start')
gnt.set_ylabel('Processor')
gnt.set_yticks([15, 25, 35])
gnt.set_yticklabels(['1', '2', '3'])
gnt.grid(True)
gnt.broken_barh([(40, 50)], (30, 9), facecolors =('tab:orange'))
gnt.broken_barh([(110, 10), (150, 10)], (10, 9), facecolors ='tab:blue')
gnt.broken_barh([(10, 50), (100, 20), (130, 10)], (20, 9), facecolors =('tab:red'))

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection ='3d')

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
data = np.random.randint(low = 1, high = 100, size = (5, 5))
print("The data to be plotted:\n")
print(data)
hm = sn.heatmap(data = data)
plt.show()
# Out:
# The data to be plotted:
#
# [[92 11  3 10 38]
#  [23 17 52 33 64]
#  [68  2  6 19 67]
#  [99 58 77 10 13]
#  [81 66 38 93  3]]

# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [2,4,1]
plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('My first graph!')
plt.show()

# %%
import pandas as pd
data = pd.read_csv("C:\\Users\sarth\OneDrive\Documents\#LAB\PY\heart.csv")
means = data.groupby('trestbps')['age'].agg('mean') 
mmax = means.idxmax()
mmin = means.idxmin()
print('mean trestbps: ' + str(means))
print('mean_max trestbps: ' + str(mmax))
print('mean_min trestbps: ' + str(mmin))
# Out:
# mean trestbps: trestbps
# 94     45.857143
# 100    57.928571
# 101    46.000000
# 102    51.000000
# 104    45.000000
# 105    48.333333
# 106    67.000000
# 108    52.666667
# 110    51.968750
# 112    52.800000
# 114    58.000000
# 115    51.666667
# 117    60.000000
# 118    45.833333
# 120    52.734375
# 122    44.928571
# 123    53.000000
# 124    55.750000
# 125    58.736842
# 126    46.400000
# 128    55.358974
# 129    50.000000
# 130    52.390244
# 132    52.642857
# 134    55.941176
# 135    55.850000
# 136    50.545455
# 138    48.800000
# 140    56.682243
# 142    48.000000
# 144    59.000000
# 145    63.823529
# 146    62.000000
# 148    52.857143
# 150    57.690909
# 152    56.235294
# 154    57.000000
# 155    65.000000
# 156    70.000000
# 160    63.888889
# 164    59.000000
# 165    57.000000
# 170    60.066667
# 172    52.000000
# 174    59.000000
# 178    63.000000
# 180    61.600000
# 192    54.000000
# 200    56.000000
# Name: age, dtype: float64
# ...
